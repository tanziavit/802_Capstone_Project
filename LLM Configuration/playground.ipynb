# %%
import os

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

# %%
from openai import OpenAI

client = OpenAI(api_key=OPENAI_API_KEY)

def generate_text(prompt):
    try:
        response = client.chat.completions.create(
            model="gpt-4o-mini",
            messages=[
                {"role": "system", "content": "You are a real estate marketing expert."},
                {"role": "user", "content": prompt}
            ],
            temperature=0.7
        )

        return response.choices[0].message.content.strip()

    except Exception as e:
        print("OpenAI Error:", str(e))
        return "Error generating content"

# %%
data = {
    "location": "Melbourne",
    "size": "1200 sq ft",
    "price": "AUD 550,000",
    "bedrooms": "3 BHK",
    "bathrooms": "2",
    "kitchen": "Modular kitchen",
    "Parking": "2 Vehicles",
    "additional_features": "Balcony"
}

# %%
prompt = f"""
Create real estate content in a formal tone.

Property Details:
Location: {data['location']}
Size: {data['size']}
Price: {data['price']}
Bedrooms: {data['bedrooms']}
Bathrooms/Toilets: {data['bathrooms']}
Kitchen: {data['kitchen']}

Additional Features:
{data['additional_features']}

Generate:
1. Property Listing Description
2. Social Media Post
3. Professional Email
4. Video Script
"""

# %%
response = generate_text(prompt)

# %%
from IPython.display import display, Markdown

display(Markdown(response))
# Out:
# ### 1. Property Listing Description
#
# **Stunning 3 BHK Apartment in the Heart of Melbourne**
#
# Introducing an exceptional opportunity to own a beautifully appointed 3-bedroom, 2-bathroom apartment located in the vibrant city of Melbourne. Spanning an impressive 1200 square feet, this residence is now available for AUD 550,000, making it an ideal investment for families and professionals alike.
#
# As you step into this elegant home, you will be greeted by a spacious living area that seamlessly flows into a modern, modular kitchen equipped with state-of-the-art appliances. The design maximizes both functionality and aesthetics, ensuring a delightful cooking experience.
#
# The apartment features three generously sized bedrooms, providing ample space for relaxation and privacy. The two well-appointed bathrooms are designed with contemporary finishes, catering to the needs of a busy household.
#
# ...
